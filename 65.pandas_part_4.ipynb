# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop("PassengerId",axis=1)                                   # axis 0 is row axis , ccolumn mwans axis is 1
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df               #perminant delect nahi kiya he
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df =df.drop("PassengerId",axis=1)      # method 1 reassign

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df = df.drop("PassengerId",axis=1,inplace=True)   # method 2 inplace
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df = df.drop("PassengerId",axis=1,inplace=True)   # method 2 inplace
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5249 def drop(  # type: ignore[override]
# ...

# %%
df.head()

# %%
df.drop(3,inplace=True)         # by defualt axit=0 means row hoi    perminant delete karva mate inplace no use thy

# %%
df

# %%
df.set_index("Name")      # name ne index bnavav mate

# %%
df    # perminant nathi thyu

# %%
 df.set_index("Name",inplace = True)

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)               1       1  female
# Allen, Mr. William Henry                                   0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df.reset_index()
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                             Allen, Mr. William Henry         0       3
# ..                                                 ...       ...     ...
# 886                              Montvila, Rev. Juozas         0       2
# 887                       Graham, Miss. Margaret Edith         1       1
# 888           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 889                              Behr, Mr. Karl Howell         1       1
# 890                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
d = {'key1' : [3,4,5,6,7,8],
     'key2' : [11,12,13,14,15,16],
     'key3' : [1,2,3,4,56,6]
}

# %%
pd.DataFrame(d)            # discnary ne data frame ma convert karva mate .... length same hovi joiye
# Out:
#    key1  key2  key3
# 0     3    11     1
# 1     4    12     2
# 2     5    13     3
# 3     6    14     4
# 4     7    15    56
# 5     8    16     6

# %% [markdown]
#            ______________ taxonomy data _____________________

# %%
import pandas as pd

# %%
pd.read_csv("taxonomy.csv.xls")
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1 =  pd.read_csv("taxonomy.csv.xls")

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna()     # NaN Data ne delete kari dese
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1.dropna(inplace=True)

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1.dropna(axis=0)         # je row ma Nan data hse e row delete kri de
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df2 = pd.read_csv("taxonomy.csv.xls")

# %%
df2
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df2.dropna(axis=1)      # column ma Nan value hse e cloumns delete kri dese
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df2.fillna("hemangi")                        # jya pn Nan value hse tene fill kari skay
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency   hemangi               hemangi
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        0            1         0       3
# 1        1            2         1       1
# 2        2            3         1       3
# 3        3            4         1       1
# 4        4            5         0       3
# ..     ...          ...       ...     ...
# 886    886          887         0       2
# 887    887          888         1       1
# 888    888          889         0       3
# 889    889          890         1       1
# 890    890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df.groupby("Survived")

# %%
g = df.groupby("Survived")

# %%
g

# %%
g.sum()
# Out:
# /tmp/ipykernel_70/1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#            index  PassengerId  Pclass       Age  SibSp  Parch        Fare
# Survived
# 0         244863       245412    1390  12985.50    304    181  12142.7199
# 1         151632       151974     667   8219.67    162    159  16551.2294

# %%
g.mean()
# Out:
# /tmp/ipykernel_70/2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#                index  PassengerId    Pclass        Age     SibSp     Parch  \
# Survived
# 0         446.016393   447.016393  2.531876  30.626179  0.553734  0.329690
# 1         443.368421   444.368421  1.950292  28.343690  0.473684  0.464912
#
#                Fare
# Survived
# 0         22.117887
# 1         48.395408

# %%
g1 = df.groupby("Pclass")

# %%
g1

# %%
g1.sum()
# Out:
# /tmp/ipykernel_70/2725926089.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.sum()
#          index  PassengerId  Survived      Age  SibSp  Parch        Fare
# Pclass
# 1        99489        99705       136  7111.42     90     77  18177.4125
# 2        81872        82056        87  5168.83     74     70   3801.8417
# 3       215134       215625       119  8924.92    302    193   6714.6951

# %%
g1.mean()
# Out:
# /tmp/ipykernel_70/3287460031.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.mean()
#              index  PassengerId  Survived        Age     SibSp     Parch  \
# Pclass
# 1       460.597222   461.597222  0.629630  38.233441  0.416667  0.356481
# 2       444.956522   445.956522  0.472826  29.877630  0.402174  0.380435
# 3       438.154786   439.154786  0.242363  25.140620  0.615071  0.393075
#
#              Fare
# Pclass
# 1       84.154687
# 2       20.662183
# 3       13.675550

# %%
g1.max()
# Out:
# /tmp/ipykernel_70/1233177901.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max()
#         index  PassengerId  Survived                         Name   Sex   Age  \
# Pclass
# 1         889          890         1     Young, Miss. Marie Grice  male  80.0
# 2         886          887         1    del Carlo, Mr. Sebastiano  male  70.0
# 3         890          891         1  van Melkebeke, Mr. Philemon  male  74.0
#
#         SibSp  Parch      Ticket      Fare
# Pclass
# 1           3      4   WE/P 5735  512.3292
# 2           3      3   W/C 14208   73.5000
# 3           8      6  W./C. 6609   69.5500

# %%
g1.max()["Fare"]
# Out:
# /tmp/ipykernel_70/32325780.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max()["Fare"]
# Pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: Fare, dtype: float64

# %%
g1.max().T             # column row bani jay and row column bane .T thi (tranpose)
# Out:
# /tmp/ipykernel_70/3498844780.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().T             # column row bani jay and row column bane .T thi (tranpose)
# Pclass                              1                          2  \
# index                             889                        886
# PassengerId                       890                        887
# Survived                            1                          1
# Name         Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Sex                              male                       male
# Age                              80.0                       70.0
# SibSp                               3                          3
# Parch                               4                          3
# ...

# %%
g1.max().transpose()
# Out:
# /tmp/ipykernel_70/3907411846.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().transpose()
# Pclass                              1                          2  \
# index                             889                        886
# PassengerId                       890                        887
# Survived                            1                          1
# Name         Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Sex                              male                       male
# Age                              80.0                       70.0
# SibSp                               3                          3
# Parch                               4                          3
# Ticket                      WE/P 5735                  W/C 14208
# ...

# %%
g1.median()
# Out:
# /tmp/ipykernel_70/517914711.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.median()
#         index  PassengerId  Survived   Age  SibSp  Parch     Fare
# Pclass
# 1       471.0        472.0       1.0  37.0    0.0    0.0  60.2875
# 2       434.5        435.5       0.0  29.0    0.0    0.0  14.2500
# 3       431.0        432.0       0.0  24.0    0.0    0.0   8.0500

# %%
df
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        0            1         0       3
# 1        1            2         1       1
# 2        2            3         1       3
# 3        3            4         1       1
# 4        4            5         0       3
# ..     ...          ...       ...     ...
# 886    886          887         0       2
# 887    887          888         1       1
# 888    888          889         0       3
# 889    889          890         1       1
# 890    890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df5 = df[['Name','Survived','Pclass']].head()

# %%
df5
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                           Allen, Mr. William Henry         0       3

# %%
df6 = df[['Name','Survived','Pclass']][5:10]

# %%
df6
# Out:
#                                                 Name  Survived  Pclass
# 5                                   Moran, Mr. James         0       3
# 6                            McCarthy, Mr. Timothy J         0       1
# 7                     Palsson, Master. Gosta Leonard         0       3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 9                Nasser, Mrs. Nicholas (Adele Achem)         1       2

# %% [markdown]
# data merge two type thi thy horiziontally and vertically

# %%
pd.concat([df5,df6])     # vertically
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                           Allen, Mr. William Henry         0       3
# 5                                   Moran, Mr. James         0       3
# 6                            McCarthy, Mr. Timothy J         0       1
# 7                     Palsson, Master. Gosta Leonard         0       3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 9                Nasser, Mrs. Nicholas (Adele Achem)         1       2

# %%
df7 = pd.concat([df5,df6],axis=1)         # horizontally

# %%
df7
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris       0.0     3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1.0     1.0
# 2                             Heikkinen, Miss. Laina       1.0     3.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1.0     1.0
# 4                           Allen, Mr. William Henry       0.0     3.0
# 5                                                NaN       NaN     NaN
# 6                                                NaN       NaN     NaN
# 7                                                NaN       NaN     NaN
# 8                                                NaN       NaN     NaN
# 9                                                NaN       NaN     NaN
#
#                                                 Name  Survived  Pclass
# 0                                                NaN       NaN     NaN
# ...

# %%
df7.fillna("hemangi")
# Out:
#                                                 Name Survived   Pclass  \
# 0                            Braund, Mr. Owen Harris      0.0      3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1.0      1.0
# 2                             Heikkinen, Miss. Laina      1.0      3.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1.0      1.0
# 4                           Allen, Mr. William Henry      0.0      3.0
# 5                                            hemangi  hemangi  hemangi
# 6                                            hemangi  hemangi  hemangi
# 7                                            hemangi  hemangi  hemangi
# 8                                            hemangi  hemangi  hemangi
# 9                                            hemangi  hemangi  hemangi
#
#                                                 Name Survived   Pclass
# 0                                            hemangi  hemangi  hemangi
# ...

# %%
data1 = pd.DataFrame({'key1' : [1,2,3,4,5],
                      'key2' : [6,7,8,9,10],
                      'key3' : [11,12,13,14,15]}
)

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     6    11
# 1     2     7    12
# 2     3     8    13
# 3     4     9    14
# 4     5    10    15

# %%
data2 = pd.DataFrame({'key1' : [1,22,3,4,55],
                      'key4' : [6,7,8,9,110],
                      'key5' : [11,112,13,144,15]}
)

# %%
data2
# Out:
#    key1  key4  key5
# 0     1     6    11
# 1    22     7   112
# 2     3     8    13
# 3     4     9   144
# 4    55   110    15

# %%
pd.merge(data1,data2)    # banne data mathi common value male
# Out:
#    key1  key2  key3  key4  key5
# 0     1     6    11     6    11
# 1     3     8    13     8    13
# 2     4     9    14     9   144

# %%
pd.merge(data1,data2,how='left')
# Out:
#    key1  key2  key3  key4   key5
# 0     1     6    11   6.0   11.0
# 1     2     7    12   NaN    NaN
# 2     3     8    13   8.0   13.0
# 3     4     9    14   9.0  144.0
# 4     5    10    15   NaN    NaN

# %%
pd.merge(data1,data2,how='right')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   6.0  11.0     6    11
# 1    22   NaN   NaN     7   112
# 2     3   8.0  13.0     8    13
# 3     4   9.0  14.0     9   144
# 4    55   NaN   NaN   110    15

# %%
pd.merge(data1,data2,how='outer',on = 'key1')
# Out:
#    key1  key2  key3   key4   key5
# 0     1   6.0  11.0    6.0   11.0
# 1     2   7.0  12.0    NaN    NaN
# 2     3   8.0  13.0    8.0   13.0
# 3     4   9.0  14.0    9.0  144.0
# 4     5  10.0  15.0    NaN    NaN
# 5    22   NaN   NaN    7.0  112.0
# 6    55   NaN   NaN  110.0   15.0

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     6    11
# 1     2     7    12
# 2     3     8    13
# 3     4     9    14
# 4     5    10    15

# %%
data2
# Out:
#    key1  key4  key5
# 0     1     6    11
# 1    22     7   112
# 2     3     8    13
# 3     4     9   144
# 4    55   110    15

# %%
pd.merge(data1,data2,how='cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     6    11       1     6    11
# 1        1     6    11      22     7   112
# 2        1     6    11       3     8    13
# 3        1     6    11       4     9   144
# 4        1     6    11      55   110    15
# 5        2     7    12       1     6    11
# 6        2     7    12      22     7   112
# 7        2     7    12       3     8    13
# 8        2     7    12       4     9   144
# 9        2     7    12      55   110    15
# 10       3     8    13       1     6    11
# 11       3     8    13      22     7   112
# 12       3     8    13       3     8    13
# 13       3     8    13       4     9   144
# 14       3     8    13      55   110    15
# 15       4     9    14       1     6    11
# 16       4     9    14      22     7   112
# 17       4     9    14       3     8    13
# 18       4     9    14       4     9   144
# 19       4     9    14      55   110    15
# 20       5    10    15       1     6    11
# ...

# %%
data1 = pd.DataFrame({'key1' : [1,2,3,4,5],
                      'key2' : [6,7,8,9,10],
                      'key3' : [11,12,13,14,15]},
                     index =['a','b','c','d','e']
)

# %%
data2 = pd.DataFrame({'key11' : [1,22,3,4,55],
                      'key41' : [6,7,8,9,110],
                      'key15' : [11,112,13,144,15]},
                     index =['a','b','j','k','m']
)

# %%
data1
# Out:
#    key1  key2  key3
# a     1     6    11
# b     2     7    12
# c     3     8    13
# d     4     9    14
# e     5    10    15

# %%
data2
# Out:
#    key11  key41  key15
# a      1      6     11
# b     22      7    112
# j      3      8     13
# k      4      9    144
# m     55    110     15

# %%
data1.join(data2)
# Out:
#    key1  key2  key3  key11  key41  key15
# a     1     6    11    1.0    6.0   11.0
# b     2     7    12   22.0    7.0  112.0
# c     3     8    13    NaN    NaN    NaN
# d     4     9    14    NaN    NaN    NaN
# e     5    10    15    NaN    NaN    NaN

# %%
data1.join(data2,how="inner")
# Out:
#    key1  key2  key3  key11  key41  key15
# a     1     6    11      1      6     11
# b     2     7    12     22      7    112

# %%
data1.join(data2,how="outer")
# Out:
#    key1  key2  key3  key11  key41  key15
# a   1.0   6.0  11.0    1.0    6.0   11.0
# b   2.0   7.0  12.0   22.0    7.0  112.0
# c   3.0   8.0  13.0    NaN    NaN    NaN
# d   4.0   9.0  14.0    NaN    NaN    NaN
# e   5.0  10.0  15.0    NaN    NaN    NaN
# j   NaN   NaN   NaN    3.0    8.0   13.0
# k   NaN   NaN   NaN    4.0    9.0  144.0
# m   NaN   NaN   NaN   55.0  110.0   15.0

# %%
data1.join(data2,how="left")
# Out:
#    key1  key2  key3  key11  key41  key15
# a     1     6    11    1.0    6.0   11.0
# b     2     7    12   22.0    7.0  112.0
# c     3     8    13    NaN    NaN    NaN
# d     4     9    14    NaN    NaN    NaN
# e     5    10    15    NaN    NaN    NaN

# %%
data1.join(data2,how="right")
# Out:
#    key1  key2  key3  key11  key41  key15
# a   1.0   6.0  11.0      1      6     11
# b   2.0   7.0  12.0     22      7    112
# j   NaN   NaN   NaN      3      8     13
# k   NaN   NaN   NaN      4      9    144
# m   NaN   NaN   NaN     55    110     15

# %%
data1.join(data2,how="cross")
# Out:
#     key1  key2  key3  key11  key41  key15
# 0      1     6    11      1      6     11
# 1      1     6    11     22      7    112
# 2      1     6    11      3      8     13
# 3      1     6    11      4      9    144
# 4      1     6    11     55    110     15
# 5      2     7    12      1      6     11
# 6      2     7    12     22      7    112
# 7      2     7    12      3      8     13
# 8      2     7    12      4      9    144
# 9      2     7    12     55    110     15
# 10     3     8    13      1      6     11
# 11     3     8    13     22      7    112
# 12     3     8    13      3      8     13
# 13     3     8    13      4      9    144
# 14     3     8    13     55    110     15
# 15     4     9    14      1      6     11
# 16     4     9    14     22      7    112
# 17     4     9    14      3      8     13
# 18     4     9    14      4      9    144
# 19     4     9    14     55    110     15
# 20     5    10    15      1      6     11
# ...

# %% [markdown]
# merge = value pr kam kre and join = index pr kam kre

# %%
df
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        0            1         0       3
# 1        1            2         1       1
# 2        2            3         1       3
# 3        3            4         1       1
# 4        4            5         0       3
# ..     ...          ...       ...     ...
# 886    886          887         0       2
# 887    887          888         1       1
# 888    888          889         0       3
# 889    889          890         1       1
# 890    890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df['Fare_INR'] = df['Fare'].apply(lambda x : x*80)

# %%
df.head()
# Out:
#    index  PassengerId  Survived  Pclass  \
# 0      0            1         0       3
# 1      1            2         1       1
# 2      2            3         1       3
# 3      3            4         1       1
# 4      4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Fare_INR
# 0      0         A/5 21171   7.2500   NaN        S   580.000
# 1      0          PC 17599  71.2833   C85        C  5702.664
# 2      0  STON/O2. 3101282   7.9250   NaN        S   634.000
# ...

# %%
def euro(x):
    return x*80

df['Fare_INR'] = df['Fare'].apply(euro)

# %%
df
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        0            1         0       3
# 1        1            2         1       1
# 2        2            3         1       3
# 3        3            4         1       1
# 4        4            5         0       3
# ..     ...          ...       ...     ...
# 886    886          887         0       2
# 887    887          888         1       1
# 888    888          889         0       3
# 889    889          890         1       1
# 890    890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df.head()
# Out:
#    index  PassengerId  Survived  Pclass  \
# 0      0            1         0       3
# 1      1            2         1       1
# 2      2            3         1       3
# 3      3            4         1       1
# 4      4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Fare_INR
# 0      0         A/5 21171   7.2500   NaN        S   580.000
# 1      0          PC 17599  71.2833   C85        C  5702.664
# 2      0  STON/O2. 3101282   7.9250   NaN        S   634.000
# ...

# %%
df['name_length'] = df['Name'].apply(len)

# %%
df
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        0            1         0       3
# 1        1            2         1       1
# 2        2            3         1       3
# 3        3            4         1       1
# 4        4            5         0       3
# ..     ...          ...       ...     ...
# 886    886          887         0       2
# 887    887          888         1       1
# 888    888          889         0       3
# 889    889          890         1       1
# 890    890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
def cat_fare(x):
    if x<10:
        return "cheap"
    elif x >= 10 and x <20:
        return "mid"
    else:
        return "high"

# %%
df["cat_fare"] = df["Fare"].apply(cat_fare)

# %%
df
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        0            1         0       3
# 1        1            2         1       1
# 2        2            3         1       3
# 3        3            4         1       1
# 4        4            5         0       3
# ..     ...          ...       ...     ...
# 886    886          887         0       2
# 887    887          888         1       1
# 888    888          889         0       3
# 889    889          890         1       1
# 890    890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...
